# %% [markdown]
# <a href="https://colab.research.google.com/github/TrilochanMishra/TrilochanMishra/blob/main/Heart_Disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import joblib
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, classification_report, f1_score, \
       recall_score, roc_curve, auc
from sklearn.ensemble import AdaBoostClassifier
import matplotlib.pyplot as plt

# %%
file_path = ""
from sklearn.utils import resample
df_minority = data[data['output'] == 0]
df_majority = data[data['output'] == 1]
df_minor_upsampled = resample(df_minority,
                              replace = True,
                              n_samples = 165,
                              random_state=123)

df_upsampled = pd.concat([df_majority, df_minor_upsampled])

labels=df_upsampled['output']
features = df_upsampled.iloc[:,:13]

X=features
y=np.ravel(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7e89828e6c62> in <cell line: 0>()
#       1 from sklearn.utils import resample
# ----> 2 df_minority = data[data['output'] == 0]
#       3 df_majority = data[data['output'] == 1]
#       4 df_minor_upsampled = resample(df_minority,
#       5                               replace = True,
#
# NameError: name 'data' is not defined
